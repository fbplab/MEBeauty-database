# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from scipy import spatial

#prepare data with generic scores

txt1 = pd.read_csv('scores/train_2022.txt', sep=" ",  header = None)
txt2 = pd.read_csv('scores/test_2022.txt', sep=" ",  header = None)
txt3 = pd.read_csv('scores/val_2022.txt', sep=" ", header = None)
data = pd.concat([txt1,txt2,txt3])
data.columns = ['image', 'score']

data = data.sort_values(by=['score'])
n_training, acc, mae, rmse = eigenface(data,'score',train_number = 1000)

print(n_training, acc, mae, rmse)
# Out:
# 1000 (0.3944638252408826, 1.5827948473807422e-52) 0.11275517264654883 0.019930713053529836

# %%
#Eigenface + shallow predictor

from scipy.stats import pearsonr
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.svm import SVR
import sklearn.metrics as metrics
from sklearn.decomposition import PCA
from PIL import Image
import matplotlib.pyplot as plt


def preprocess_data(faces_train, faces_test):
    # flatten the imagaes from 
    X_train =  np.reshape(faces_train,(faces_train.shape[0], -1 ))
    X_test =   np.reshape(faces_test, (faces_test.shape[0], -1 ))
    mu = np.mean(X_train, axis = 0 )
    std_dev = np.mean(X_train, axis = 0)
    std_dev_mod = np.copy(std_dev)
    std_dev_mod[std_dev == 0 ] = 1
    X_train = (X_train - mu)/std_dev_mod
    # normalize the test set with same mu and std values as training set 
    X_test = (X_test - mu)/std_dev_mod
    return X_train, X_test  


def preprocess_data2(faces_train, faces_test):
    
    
    normalised_train = np.ndarray(shape=(len(faces_train), 224*224))
    normalised_test = np.ndarray(shape=(len(faces_test), 224*224))
    
    mean_face = np.zeros((1,224*224))

    for i in faces_train:
       mean_face = np.add(mean_face,i)
    
    mean_face = np.divide(mean_face,float(len(faces_train))).flatten()

    plt.imshow(mean_face.reshape(224, 224), cmap='gray')
    
    for i in range(len(faces_train)):
       normalised_train[i] = np.subtract(faces_train[i],mean_face)
    
    for i in range(len(faces_test)):
       normalised_test[i] = np.subtract(faces_test[i],mean_face)
    
    return normalised_train, normalised_test


def eigenface(df,column, train_number = 100):
       k=0
       df = df.sample(frac=1).reset_index(drop=True)
       df['image'] =df['image'].str.replace('/home/ubuntu/ME-beautydatabase/images',
                                                '/home/ubuntu/MEBeauty-database/images_crop_align_mtcnn') 
       
       min_max_scaler = preprocessing.MinMaxScaler()
    
       df[column] = min_max_scaler.fit_transform(df[column].values.reshape(-1,1))
    
       df2 = pd.DataFrame(columns = ['image', column, 'features'])
    
       for index, row in df.iterrows():

          try:
             
             img = Image.open(row['image']).convert('L')
             df2.loc[len(df2)]=[row['image'],row[column], np.asarray(img).flatten()]
                
          except:
            
             #print(row['image'])
             k+=k   
             pass
       
       
       #normalized_df=(df2-df2.mean())/df2.std()
       
       scaler = StandardScaler()
        
       train= df2[:train_number]
       test= df2[train_number:]
       #one_test = test.iloc[[55]]
       regressor = SVR(kernel = 'linear') 
        

       
       #train_X = (train['features'].values.tolist())    
       #test_X = (test['features'].values.tolist()) 

       train_X = min_max_scaler.fit_transform(train['features'].values.tolist())    
       test_X = min_max_scaler.fit_transform(test['features'].values.tolist())
       #train_X, test_X = preprocess_data2(train_X, test_X)
       train_Y = (train[column].values.tolist()) 
       test_Y = (test[column].values.tolist())
       #print(train_Y[10])
        
       fig = plt.figure()
       fig.add_subplot(1, 4, 1)
       plt.imshow(train_X[200].reshape(224,224), cmap='gray')
       fig.add_subplot(1, 4, 2)
       plt.imshow(train_X[300].reshape(224,224), cmap='gray')
       fig.add_subplot(1, 4, 3)
       plt.imshow(train_X[400].reshape(224,224), cmap='gray')
       fig.add_subplot(1, 4, 4)
       plt.imshow(train_X[500].reshape(224,224), cmap='gray') 
        
       n_components = 50
       pca = PCA(n_components = 50, whiten=True).fit(train_X)
       # apply PCA transformation
       X_train_pca = pca.transform(train_X)
       X_test_pca = pca.transform(test_X) 
      
       fig = plt.figure()
       plt.imshow(pca.mean_.reshape(224,224),
           cmap=plt.cm.bone)
    
       fig = plt.figure(figsize=(16, 6))
       for i in range(30):
           ax = fig.add_subplot(3, 10, i + 1, xticks=[], yticks=[])
           ax.imshow(pca.components_[i].reshape(224,224),
              cmap=plt.cm.bone)
    
       regressor.fit(X_train_pca, train_Y)
       #w = regressor.coef_.dot(np.asarray(one_test['features'].values.tolist()).reshape(512))
       result = regressor.predict(X_test_pca) 
       #print(result[:100])
       #print(result[55],w+regressor.intercept_)
       mae =  metrics.mean_absolute_error(test_Y, result)
       rmse = metrics.mean_squared_error(test_Y, result)
       return train_number, pearsonr(test_Y, result), mae, rmse

# %%
# Gabor, HOF, SIFT, 

import numpy as np
from cv2 import cv2
import cv2 as cv
import os
from skimage.feature import hog

#import csv


EPS = 0.00000000000000001

def build_filters():
    filters = []

    # Size of Gabor kernel
    ksize = 31

    # For different orientations
    for theta in np.arange(0, np.pi, np.pi/4):
        # And different wavelengths of the sinusoidal factor
        for lamb in np.arange(np.pi/4, np.pi, np.pi/4):
            # Get a filter
            kern = cv2.getGaborKernel((ksize, ksize), 4.0, theta, lamb, 0.5, 0, ktype=cv2.CV_32F)
            kern /= 1.5*kern.sum()
            filters.append(kern)

    return filters
 
# Given an image and a set of filters, derive the response matrices 
def process(img, filters):
    img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (100,100))

    responses = []
    # accum = np.zeros_like(img)
    for kern in filters:
        fimg = cv2.filter2D(img, cv2.CV_8UC3, kern)
        responses.append(fimg)
        # np.maximum(accum, fimg, accum)

    return responses

# Given a response matrix, compute for the local energy
# Local Energy = summing up the squared value of each matrix value from a response matrix
def get_local_energy (matrix):
    local_energy = 0.0
    for row in range (len(matrix)):
        for col in range(len(matrix[0])):
            val = int(matrix[row][col]) * int(matrix[row][col])
            local_energy = local_energy + val

    # Divide by the highest possible value, which is 255^2 * (100 x 100)
    # to normalize values from 0 to 1, and replace 0s with EPS value to work with NB
    local_energy = local_energy / 650250000
    return EPS if local_energy == 0 else local_energy

# Given a response matrix, compute for the mean amplitude
# Mean Amplitude = sum of absolute values of each matrix value from a response matrix
def get_mean_amplitude (matrix):
    mean_amp = 0.0

    for row in range (len(matrix)):
        for col in range(len(matrix[0])):
            val = abs(int(matrix[row][col]))
            mean_amp = mean_amp + val

    # Divide by the highest possible value, which is 255 * (100 x 100)
    # to normalize values from 0 to 1, and replace 0s with EPS value to work with NB
    mean_amp = mean_amp / 2550000
    return EPS if mean_amp == 0 else mean_amp

# Return a list of images from the given directory
def load_images_from_folder (folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        if img is not None:
            images.append(img)
    return images

# Get the feature vector (local energy/mean amplitude from response matrices) of an image
# This function is called when bulding the CSV files or when processing each frame
def get_image_feature_vector(image, filters, positive=None):
    response_matrices = process(image, filters)

    local_energy_results = []
    mean_amplitude_results = []

    for matrix in response_matrices:
        local_energy = get_local_energy(matrix)
        mean_amplitude = get_mean_amplitude(matrix)
        local_energy_results.append (local_energy)
        mean_amplitude_results.append(mean_amplitude)
        
    if positive is None:
        feature_set = local_energy_results + mean_amplitude_results
    else:
        pos_num = 1 if positive else 0
        feature_set = local_energy_results + mean_amplitude_results + [pos_num]

    return feature_set

# Get all feature vectors of a set of images, used when building the CSV files
def get_all_image_feature_vectors(df, column, features_type = "gabor"):
    filters = build_filters()
    feature_sets = []
    df2 = pd.DataFrame(columns = ['image', column, 'features'])
    
    for index, row  in df.iterrows():
        try: 
           img = cv2.imread(row['image'])

           
           if features_type == 'HOG1':  
            
              img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
              img = cv2.resize(img,(128,128))
              # compute HOG features
              features, hog_image = hog(img, orientations=8, pixels_per_cell=(16, 16), cells_per_block=(4, 4), block_norm= 'L2',visualize=True)
           
           elif features_type == 'HOG2': 
                
              
              img=cv2.resize(img, (64, 128), interpolation=cv2.INTER_CUBIC)  
              hog_cv=cv2.HOGDescriptor()
              
              features=hog_cv.compute(img,winStride=(64,128),padding=(0,0))  
              features=features.transpose()
              features = np.squeeze(features)  
           elif features_type == 'SIFT':
             
              #not working right now
              
              sift = cv2.SIFT_create()
              # compute SIFT keypoints & descriptors for images
              kp, features= sift.detectAndCompute(img, None)
               
              features = features.flatten()
             
           else:
              
              features = get_image_feature_vector(img, filters, positive=False)   
            
           df2.loc[len(df2)] = [row['image'],row[column],features] 
        except:
           print(row['image'])
    return df2



import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from scipy import spatial

#prepare data with generic scores

txt1 = pd.read_csv('scores/train_2022.txt', sep=" ",  header = None)
txt2 = pd.read_csv('scores/test_2022.txt', sep=" ",  header = None)
txt3 = pd.read_csv('scores/val_2022.txt', sep=" ", header = None)
data = pd.concat([txt1,txt2,txt3])
data.columns = ['image', 'score']
data.image  = data.image.str.replace('/home/ubuntu/ME-beautydatabase/images/','/home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/')

df = get_all_image_feature_vectors (data,'score',features_type = 'gabor')
# Out:
#                                                  image     score
# 0    /home/ubuntu/MEBeauty-database/images_crop_ali...  3.790123
# 1    /home/ubuntu/MEBeauty-database/images_crop_ali...  7.663194
# 2    /home/ubuntu/MEBeauty-database/images_crop_ali...  4.561957
# 3    /home/ubuntu/MEBeauty-database/images_crop_ali...  5.960920
# 4    /home/ubuntu/MEBeauty-database/images_crop_ali...  5.046717
# ..                                                 ...       ...
# 225  /home/ubuntu/MEBeauty-database/images_crop_ali...  7.405896
# 226  /home/ubuntu/MEBeauty-database/images_crop_ali...  6.100000
# 227  /home/ubuntu/MEBeauty-database/images_crop_ali...  7.427273
# 228  /home/ubuntu/MEBeauty-database/images_crop_ali...  4.888889
# 229  /home/ubuntu/MEBeauty-database/images_crop_ali...  6.460268
#
# [2553 rows x 2 columns]
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/caucasian/g_7.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/ashkan-forouzani-lxQw4HiwKBY-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/happiness-4067230_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/caucasian/model-4493512_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/man-921004_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pedram-normohamadian-daguyNdZFCY-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-askar-abayev-5638731.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/indian/brown-4197806_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-nishant-aneja-2561432.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/swapnil-dwivedi-N2IJ31xZ_ks-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/puvvukonvict-photography-AtpSEe3yoIg-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/portrait-2612525_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/jeffrey-grospe-epomvImeev4-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/theodore-goutas-aeq3jJj0sUw-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/mideastern/guy14.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/caucasian/brunette-2478405_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/dollar-gill-nGWo2KbJERc-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/mideastern/jonathan-borba-5rQG1mib90I-unsplash (1).jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/safal-karki-_p93Zag8tgE-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/model-633771_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/handsome-1886567_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/hichem-dahmani-8VitrkP2-mw-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-yogendra-singh-3748221.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/kazi-mizan-bfReptWpKEg-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/muhammad-ali-2LTkVBl6ViM-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-ali-madad-sakhirani-997512.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/portrait-2552312_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/imansyah-muhamad-putera-Ob19pmoYWkI-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/md-duran-3pe-sQM8-28-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/boy-5838699_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-john-stephenson-5308640.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/ali-yahya-22S6KHZoE8Q-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/ilaya-raja-uX0yUOEYFFU-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/shudipto-sarker-9qpe5gZDc7E-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/usman-yousaf-xYzEQptq7XU-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/white-1513923_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-rahul-shah-888956.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/ankush-minda-uPIDtOdCINY-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/guy10.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/man-5465741_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/abhimanyu-patel-o2g-PaaeD_U-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/indian/shifaaz-shamoon-MqLy-G-dBi8-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/vishal-shiro-5935497_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/jaikishan-patel-G1r9ySGtdWQ-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/hispanic/mateus-campos-felipe-64sktAOWasI-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/portrait-419946_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/portrait-2181213_1280.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/kazi-mizan-PDDfWeh44m8-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/boy-1119239_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/one-5889887_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/ashkan-forouzani-Y8QiDJMEUGc-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/noorulabdeen-ahmad-nDrV5Wq2lxU-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/aryan-ghauri-dRatGbY1k8Y-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/naga-sajjanapu-zXds99Aem5E-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/shudipto-sarker-IoFK2MP2aJ0-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/sazzad-aryan-rjm8go9rL8Y-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/md-rakib-SW_pFXUOjTQ-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/kamran-ch-7pES3XC7l7Q-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-dhemer-gonçalves-3036415.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/india-4870636_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/indian-5882625_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/kids-2408614_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/shivam-singh-DOmEd6CYP5M-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/rohan-g-T9ckn3XHHnA-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/man-3346780_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/man-2367954_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-yogendra-singh-5499219.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/muhammad-abdullah-hAnMkbSsDMs-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/couple-engagement-pictures-2136097_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/dollar-gill-X0iNZ0UZIrI-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/amir-soltani-9RcccOHau2M-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/shivam-singh-DOmEd6CYP5M-unsplash(1).jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/muhammad-murtaza-ghani-nUjfEYmJYl0-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-sora-shimazaki-5935750.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/nith-in-w1N1WmLDyHU-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/caucasian/boy-1105361_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/hadi-yazdi-aznaveh-TmRQRgugEsQ-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/asian/tanjir-ahmed-chowdhury-YMJvX8k3Kfc-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/md-duran-msnDjv5cC_U-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-the-baljinder-4089881.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/caucasian/charlize-theron-669608_1280.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-prince-photos-1537517.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/sammy-chandio-EvdFPEFqoxk-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/puvvukonvict-photography-0M_Aej4dRWU-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/amir-ahmadpour-UtaI5TkADPw-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/black/payton-tuttle-n_RdRxH_7h4-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/caucasian/vicky-hladynets-NnmUHZ6tpSs-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/portrait-2529905_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/rahadiansyah-3RQEJUpu-Dc-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-ketut-subiyanto-4307733.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/male-model-1221915_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/diego-sanchez-ABNwyVyvCbo-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/muhammad-murtaza-ghani-iDN_Q0zSvY8-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/caucasian/girl2.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/shivam-singh-2_X6NMP-E_U-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/head-shots-1544781_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/black/woman-984426_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/jaikishan-patel-DSyyWrVjBNA-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/indian-boy-2982850_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/ecommerce-3412872_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/jennifer-marquez-kg9cClY_fuc-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/10.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/hispanic/girl1.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/jyotirmoy-gupta-nBe68MZSIYY-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/deepak-mahajan-8ig-SzHpqDw-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/muhammad-murtaza-ghani-65fj5U5HQek-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/man-3733308_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/man-5940355_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/115.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/muhammad-murtaza-ghani-Qt6x9oQ3H08-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/guy7.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/caucasian/man-5880780_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/sexy-1469502_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/male-5198715_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/mideastern/imad-clicks-2_qmEnz7bQ4-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/harps-joseph-tAvpDE7fXgY-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/nehal-patel-aho7nVdauuc-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/jordyn-montague-nV7GRL8ooJg-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/asian/pexels-rodnae-productions-4911184.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/salman-ahmad-JBxAQ_Blorw-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/juanma-velasquez-JrNsKhB5aRQ-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-daniel-xavier-1212984.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/people-3358068_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-fauxels-3184408.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/india-1129954_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/emiliano-vittoriosi-XtmpHM7uKCs-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/himanshu-dewangan-brk2ZfYTOp8-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/caucasian/creating-a-brand-WxAOdbDpMiU-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/gaurav-khoda-HYQMk4fFI-s-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/children-82272_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/mitchell-luo-mVSlJeuqtL0-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/caucasian/man-1488305_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/samir-basnet-qRmHuCrJkYY-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/man-2933801_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/116.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/hossein-rezaei--paUf05gaUs-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/rahabi-khan-eNafqf_0ZWQ-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/asian/pexels-kevin-kabore-4966995.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-ibadat-singh-2955247.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/yogendra-singh-DFyFd76t1NY-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/alex-avalos-Mfoj3mxvYl8-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/mitchell-luo-Mp8ZXtgR_Lg-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/indian-3459541_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/young-1761404_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/caucasian/montgomery-clift-402456_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/caucasian/esther-williams-402543_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/evan-dvorkin-FLhnC9S_UE8-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/hispanic/islander-images-kwHBTNUQIqs-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/128.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/kazi-mizan-S3FoV56-Wbk-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/muhammad-murtaza-ghani-Z5zPPTDQtHU-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/md-duran-RhIXw1Ua-NI-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/lijo-easo-1JEg1c--_dM-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/ali-kazal-Su_3F-rsTFE-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/ashkan-forouzani-YlAp3Y7VUmA-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/farhan-shaikh-9TYryqt3wLk-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/black/doil-oh-v15GcVql4CM-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-anna-tarazevich-5119607.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/female/indian/pexels-nh-noyon-4250862.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/suranjan-koirala-95-3iy_pj2I-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/ashkan-forouzani-b8dhPVAxWfE-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/man-5465729_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/muhammad-murtaza-ghani-ShxuPMbO1lM-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/caucasian/g_9.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/people-2456350_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/guy3.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/portrait-1469500_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/ashkan-forouzani-L9YcNysgL94-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/chirag-dulyan-qOd6UZdvMC4-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/pexels-zain-ali-905470.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/people-3231960_1920.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/athul-krishna-kmrgLHTOo8s-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/indian/eric-joseph-GMCsqQHOW0A-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/hispanic/aryo-lahap-ZVc4Zg4TY8s-unsplash.jpg
# /home/ubuntu/MEBeauty-database/images_crop_align_mtcnn/male/caucasian/business-man-1385050_1920.jpg

# %%
       
       from sklearn.svm import SVR
       from sklearn.pipeline import make_pipeline
       from sklearn.preprocessing import StandardScaler
       from scipy.stats import pearsonr
       import sklearn.metrics as metrics
       from sklearn import preprocessing
       column = 'score'
       df = df.sample(frac=1).reset_index(drop=True)
       
       min_max_scaler = preprocessing.MinMaxScaler()
    
       df[column] = min_max_scaler.fit_transform(df[column].values.reshape(-1,1))  
    
       
       train_number = 1000
       train= df[:train_number]
       test= df[train_number:]
       regressor = SVR(kernel = 'rbf')
       
       train_X = (train['features'].values.tolist())    
       test_X = (test['features'].values.tolist())
       #train_X = min_max_scaler.fit_transform(train['features'].values.tolist())    
       #test_X = min_max_scaler.fit_transform(test['features'].values.tolist())
       train_Y = (train[column].values.tolist()) 
       test_Y = (test[column].values.tolist())
      
       #print(train_Y[:60])
        
       regressor.fit(train_X, train_Y)
       #w = regressor.coef_.dot(np.asarray(one_test['features'].values.tolist()).reshape(512))
       result = regressor.predict(test_X) 
       print(result[:100])
       #print(result[55],w+regressor.intercept_)
       mae =  metrics.mean_absolute_error(test_Y, result)
       rmse = metrics.mean_squared_error(test_Y, result)
       PC = pearsonr(test_Y, result)
       PC,mae,rmse
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-7463bdca4e89> in <module>
#      27 #print(train_Y[:60])
#      28
# ---> 29 regressor.fit(train_X, train_Y)
#      30 #w = regressor.coef_.dot(np.asarray(one_test['features'].values.tolist()).reshape(512))
#      31 result = regressor.predict(test_X)
#
# ~/anaconda3/envs/tensorflow_p37/lib/python3.7/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     169             X, y = self._validate_data(X, y, dtype=np.float64,
#     170                                        order='C', accept_sparse='csr',
# --> 171                                        accept_large_sparse=False)
#     172
#     173         y = self._validate_targets(y)
#
# ~/anaconda3/envs/tensorflow_p37/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~/anaconda3/envs/tensorflow_p37/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/envs/tensorflow_p37/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     819                     ensure_min_samples=ensure_min_samples,
#     820                     ensure_min_features=ensure_min_features,
# --> 821                     estimator=estimator)
#     822     if multi_output:
#     823         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# ~/anaconda3/envs/tensorflow_p37/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/envs/tensorflow_p37/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~/anaconda3/envs/tensorflow_p37/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: setting an array element with a sequence.

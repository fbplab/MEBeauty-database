# %%
# !git init
# Out:
# Reinitialized existing Git repository in /home/ubuntu/ECUST_FBP/.git/

# %%
# !git add .

# %%
# !git commit -m "images and scores added"
# Out:
# [master (root-commit) a4c000c] images and scores added
#  Committer: Ubuntu <ubuntu@ip-172-31-22-80.us-east-2.compute.internal>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly. Run the
# following command and follow the instructions in your editor to edit
# your configuration file:
#
#     git config --global --edit
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  2340 files changed, 55 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Untitled.ipynb
#  create mode 100644 female/asian/13.jpg
#  create mode 100644 female/asian/20.jpg
#  create mode 100644 female/asian/21.jpg
#  create mode 100644 female/asian/23.jpg
#  create mode 100644 female/asian/24.jpg
#  create mode 100644 female/asian/30.jpg
# ...

# %%
# !git remote add origin https://github.com/fbplab/ECUST-beautydatabase.git

# %%
# !git remote -v
# Out:
# origin	https://github.com/fbplab/ECUST-beautydatabase.git (fetch)
# origin	https://github.com/fbplab/ECUST-beautydatabase.git (push)
